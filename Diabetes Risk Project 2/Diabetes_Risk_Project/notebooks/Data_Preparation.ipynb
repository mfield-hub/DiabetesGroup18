# %%
import numpy as np 
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('../data/Diabetes_and_LifeStyle_Dataset_.csv')

# %%
print("Missing values before")
df.isnull().sum()
# Out:
# Missing values before
# Age                                   0
# gender                                0
# ethnicity                             0
# education_level                       0
# income_level                          0
# employment_status                     0
# smoking_status                        0
# alcohol_consumption_per_week          0
# physical_activity_minutes_per_week    0
# diet_score                            0
# sleep_hours_per_day                   0
# screen_time_hours_per_day             0
# family_history_diabetes               0
# hypertension_history                  0
# cardiovascular_history                0
# bmi                                   0
# waist_to_hip_ratio                    0
# systolic_bp                           0
# diastolic_bp                          0
# heart_rate                            0
# cholesterol_total                     0
# hdl_cholesterol                       0
# ldl_cholesterol                       0
# triglycerides                         0
# glucose_fasting                       0
# glucose_postprandial                  0
# insulin_level                         0
# hba1c                                 0
# diabetes_risk_score                   0
# diabetes_stage                        0
# diagnosed_diabetes                    0
# dtype: int64

# %%
print("Duplicates before:", df.duplicated().sum())
df.drop_duplicates(inplace=True)
print("Duplicates after:", df.duplicated().sum())
# Out:
# Duplicates before: 0
# Duplicates after: 0

# %%
# Show columns
print(df.columns)

# Define target variable
target = "diabetes_stage"

# Features = everything except target
X = df.drop(columns=[target])
y = df[target]
# Out:
# Index(['Age', 'gender', 'ethnicity', 'education_level', 'income_level',
#        'employment_status', 'smoking_status', 'alcohol_consumption_per_week',
#        'physical_activity_minutes_per_week', 'diet_score',
#        'sleep_hours_per_day', 'screen_time_hours_per_day',
#        'family_history_diabetes', 'hypertension_history',
#        'cardiovascular_history', 'bmi', 'waist_to_hip_ratio', 'systolic_bp',
#        'diastolic_bp', 'heart_rate', 'cholesterol_total', 'hdl_cholesterol',
#        'ldl_cholesterol', 'triglycerides', 'glucose_fasting',
#        'glucose_postprandial', 'insulin_level', 'hba1c', 'diabetes_risk_score',
#        'diabetes_stage', 'diagnosed_diabetes'],
#       dtype='str')

# %%
# Convert categorical columns to numbers
df_encoded = pd.get_dummies(df, drop_first=True)

print(df_encoded.head())
# Out:
#    Age  alcohol_consumption_per_week  physical_activity_minutes_per_week  \
# 0   58                             0                                 215
# 1   52                             1                                 143
# 2   60                             1                                  57
# 3   74                             0                                  49
# 4   46                             1                                 109
#
#    diet_score  sleep_hours_per_day  screen_time_hours_per_day  \
# 0         5.7                  7.9                        7.9
# 1         6.7                  6.5                        8.7
# 2         6.4                 10.0                        8.1
# 3         3.4                  6.6                        5.2
# 4         7.2                  7.4                        5.0
#
#    family_history_diabetes  hypertension_history  cardiovascular_history  \
# 0                        0                     0                       0
# 1                        0                     0                       0
# 2                        1                     0                       0
# 3                        0                     0                       0
# 4                        0                     0                       0
#
#     bmi  ...  income_level_Upper-Middle  employment_status_Retired  \
# 0  30.5  ...                      False                      False
# 1  23.1  ...                      False                      False
# 2  22.2  ...                      False                      False
# 3  26.8  ...                      False                       True
# 4  21.2  ...                      False                       True
#
#    employment_status_Student  employment_status_Unemployed  \
# 0                      False                         False
# 1                      False                         False
# 2                      False                          True
# 3                      False                         False
# 4                      False                         False
#
#    smoking_status_Former  smoking_status_Never  diabetes_stage_No Diabetes  \
# 0                  False                  True                       False
# 1                   True                 False                        True
# 2                  False                  True                       False
# 3                  False                  True                       False
# 4                  False                  True                       False
#
#    diabetes_stage_Pre-Diabetes  diabetes_stage_Type 1  diabetes_stage_Type 2
# 0                        False                  False                   True
# 1                        False                  False                  False
# 2                        False                  False                   True
# 3                        False                  False                   True
# 4                        False                  False                   True
#
# [5 rows x 46 columns]

# %%
# Clean column names
df.columns = df.columns.str.lower().str.replace(" ", "_")

# Separate target
target = "diabetes_stage"
X = df.drop(columns=[target])
y = df[target]

# Encode features
X_encoded = pd.get_dummies(X, drop_first=True)

# Scale
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# %%
print("Final dataset shape:", df_encoded.shape)
# Out:
# Final dataset shape: (97297, 46)
